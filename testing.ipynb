# %%
from be_ethical import getScrapingPossibilities,checkUrlPermission

links=['https://www.youtube.com',
       'https://www.x.com',
       'https://www.wikipedia.com',
       'https://www.instagram.com',
       'https://www.facebook.com',
       'https://news.yahoo.com/',
       'https://coinmarketcap.com/']

for link in links:
    print(link)
    scraping_possibilities = getScrapingPossibilities(root_link=link,create_excel=True,silence=False)
    display(scraping_possibilities)
# Out:
# https://www.youtube.com
# (True,
#  {'Restricted': ['/api/',
#    '/comment',
#    '/feeds/videos.xml',
#    '/get_video',
#    '/get_video_info',
#    '/get_midroll_info',
#    '/live_chat',
#    '/login',
#    '/qr',
#    '/results',
#    '/signup',
#    '/t/terms',
#    '/timedtext_video',
#    '/verify_age',
#    '/watch_ajax',
#    '/watch_fragments_ajax',
#    '/watch_popup',
#    '/watch_queue_ajax',
#    '/youtubei/']})
# https://www.x.com
# Trouble sending request for "https://www.x.com/robots.txt":
# --> ConnectTimeout: HTTPSConnectionPool(host='www.x.com', port=443): Max retries exceeded with url: /robots.txt (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x00000294B56B7110>, 'Connection to www.x.com timed out. (connect timeout=None)'))
# (False, {})
# https://www.wikipedia.com
# (True,
#  {'Allowed': ['/w/api.php?action=mobileview&',
#    '/w/load.php?',
#    '/api/rest_v1/?doc'],
#   'Restricted': ['/w/',
#    '/api/',
#    '/trap/',
# ...

# %%
checkUrlPermission(link='https://coinmarketcap.com/community/sasd/topics/asdasd/',scraping_possibilities=scraping_possibilities)
# Out:
# False
